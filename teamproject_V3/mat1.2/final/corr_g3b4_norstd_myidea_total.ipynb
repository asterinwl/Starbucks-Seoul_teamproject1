# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pandas_profiling

# %%
data = pd.read_csv('my-idea.csv',encoding='ansi')  #3개년

# %%
data.columns
# Out:
# Index(['index', 'g3b4', 'gu', 'dong', 'high_count', 'low_count',
#        'high_bus_sum', 'low_bus_sum', 'high_sub_average', 'low_sub_average',
#        'average_trade', 'average_sizetrade', 'year'],
#       dtype='object')

# %%
data=data.drop(['index','gu','dong','year'],axis=1)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
# define the scaler
trans = MinMaxScaler()

# %%
# transform the data
data = trans.fit_transform(data)

# %%
from sklearn.preprocessing import StandardScaler

# %%
# define the scaler
trans = StandardScaler()

# %%
# transform the data
data = trans.fit_transform(data)

# %%
data=pd.DataFrame(data,columns=['g3b4','high_count','low_count','high_bus_sum','low_bus_sum','high_sub_average','low_sub_average','average_trade','average_sizetrade'])

# %%
data.describe()
# Out:
#                g3b4    high_count     low_count  high_bus_sum   low_bus_sum  \
# count  1.530000e+02  1.530000e+02  1.530000e+02  1.530000e+02  1.530000e+02
# mean   6.675851e-17 -3.773307e-17 -2.902544e-17  6.530724e-18  1.741526e-17
# std    1.003284e+00  1.003284e+00  1.003284e+00  1.003284e+00  1.003284e+00
# min   -1.148121e+00 -6.256947e-01 -9.140164e-01 -5.200791e-01 -7.525030e-01
# 25%   -1.148121e+00 -5.265939e-01 -9.140164e-01 -5.200791e-01 -7.525030e-01
# 50%    8.709883e-01 -4.274932e-01 -3.189334e-01 -3.279422e-01 -2.170009e-01
# 75%    8.709883e-01  6.801029e-02  2.761496e-01 -5.346104e-02  3.185013e-01
# max    8.709883e-01  4.131139e+00  3.846648e+00  5.738092e+00  5.316521e+00
#
#        high_sub_average  low_sub_average  average_trade  average_sizetrade
# count      1.530000e+02     1.530000e+02   1.530000e+02       1.530000e+02
# mean       6.966105e-17     9.288140e-17  -5.805088e-17      -1.625425e-16
# ...

# %%
corr = data.corr()

# %%
print(corr)
# Out:
#                        g3b4  high_count  low_count  high_bus_sum  low_bus_sum  \
# g3b4               1.000000    0.439040   0.002926      0.326566    -0.242076
# high_count         0.439040    1.000000   0.439899      0.907998     0.206106
# low_count          0.002926    0.439899   1.000000      0.412435     0.762522
# high_bus_sum       0.326566    0.907998   0.412435      1.000000     0.276765
# low_bus_sum       -0.242076    0.206106   0.762522      0.276765     1.000000
# high_sub_average   0.266034    0.130336   0.086581      0.117131     0.057541
# low_sub_average   -0.073454    0.187508   0.365765      0.140758     0.230238
# average_trade      0.719689    0.457658   0.056046      0.322388    -0.122933
# average_sizetrade  0.750224    0.406077   0.035916      0.277278    -0.108983
#
#                    high_sub_average  low_sub_average  average_trade  \
# g3b4                       0.266034        -0.073454       0.719689
# ...

# %%
sns.heatmap(corr, cmap='viridis')
plt.show()

# %%
data.profile_report()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.12.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2021-07-14 10:38:33.014379&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...
