# %%
import seaborn as sns

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('acp.csv')

# %%
df=df.replace('강남구','g1')

# %%
df=df.replace('서초구','g2')

# %%
df=df.replace('송파구','g3')

# %%
df=df.replace('강북구','b1')

# %%
df=df.replace('노원구','b2')

# %%
df=df.replace('도봉구','b3')

# %%
df=df.replace('성북구','b4')

# %%
df
# Out:
#     Unnamed: 0  year  gu_num  gu dong  average_sizetrade  high_count  \
# 0            0  2018       1  g1  개포동        2350.950643           1
# 1            1  2018       1  g1  논현동        1199.528213          20
# 2            2  2018       1  g1  대치동        1929.110361          26
# 3            3  2018       1  g1  도곡동        1478.389307           6
# 4            4  2018       1  g1  삼성동        1773.421078          20
# ..         ...   ...     ...  ..  ...                ...         ...
# 94          94  2020       1  g3  삼전동        1001.929997           1
# 95          95  2020       1  g3  석촌동        1348.555295           2
# 96          96  2020       1  g3  송파동        1462.550151           3
# 97          97  2020       1  g3  오금동        1250.131272           2
# 98          98  2020       1  g3  잠실동        2379.483057           7
#
#     low_count  high_bus_sum  low_bus_sum  high_sub_average  low_sub_average  \
# 0           0             5            0       1029.502388         0.000000
# 1           1            52            2        419.248044       134.404242
# 2           0            45            0        514.592509         0.000000
# 3           1            28            4        413.885034       162.182751
# 4           0            45            0        470.455989         0.000000
# ..        ...           ...          ...               ...              ...
# 94          1             0            1        352.353654       580.516526
# 95          0             4            0        410.145664         0.000000
# 96          0             4            0        311.293944         0.000000
# 97          0             5            0        190.955578         0.000000
# 98          1             9            4        551.555746       177.950204
#
#          pop_avg
# 0   6.263082e+05
# 1   2.002405e+06
# 2   2.275593e+06
# 3   1.288201e+06
# 4   1.542360e+06
# ..           ...
# 94  5.355902e+06
# 95  5.186844e+06
# 96  5.279196e+06
# 97  3.409495e+06
# 98  7.837714e+06
#
# [99 rows x 13 columns]

# %%
g3=df[(df['gu_num']==1)]

# %%
g3
# Out:
#     Unnamed: 0  year  gu_num  gu dong  average_sizetrade  high_count  \
# 0            0  2018       1  g1  개포동        2350.950643           1
# 1            1  2018       1  g1  논현동        1199.528213          20
# 2            2  2018       1  g1  대치동        1929.110361          26
# 3            3  2018       1  g1  도곡동        1478.389307           6
# 4            4  2018       1  g1  삼성동        1773.421078          20
# ..         ...   ...     ...  ..  ...                ...         ...
# 94          94  2020       1  g3  삼전동        1001.929997           1
# 95          95  2020       1  g3  석촌동        1348.555295           2
# 96          96  2020       1  g3  송파동        1462.550151           3
# 97          97  2020       1  g3  오금동        1250.131272           2
# 98          98  2020       1  g3  잠실동        2379.483057           7
#
#     low_count  high_bus_sum  low_bus_sum  high_sub_average  low_sub_average  \
# 0           0             5            0       1029.502388         0.000000
# 1           1            52            2        419.248044       134.404242
# 2           0            45            0        514.592509         0.000000
# 3           1            28            4        413.885034       162.182751
# 4           0            45            0        470.455989         0.000000
# ..        ...           ...          ...               ...              ...
# 94          1             0            1        352.353654       580.516526
# 95          0             4            0        410.145664         0.000000
# 96          0             4            0        311.293944         0.000000
# 97          0             5            0        190.955578         0.000000
# 98          1             9            4        551.555746       177.950204
#
#          pop_avg
# 0   6.263082e+05
# 1   2.002405e+06
# 2   2.275593e+06
# 3   1.288201e+06
# 4   1.542360e+06
# ..           ...
# 94  5.355902e+06
# 95  5.186844e+06
# 96  5.279196e+06
# 97  3.409495e+06
# 98  7.837714e+06
#
# [66 rows x 13 columns]

# %%
bed4=df[(df['gu_num']==0)]

# %%
bed4
# Out:
#     Unnamed: 0  year  gu_num  gu   dong  average_sizetrade  high_count  \
# 9            9  2018       0  b1    미아동         611.833019           3
# 10          10  2018       0  b1     번동         516.053450           2
# 11          11  2018       0  b1    수유동         460.761541           2
# 12          12  2018       0  b2    공릉동         559.081931           2
# 13          13  2018       0  b2    상계동         619.543514           5
# 14          14  2018       0  b2    월계동         602.432435           2
# 15          15  2018       0  b3     창동         608.136497           1
# 21          21  2018       0  b4    길음동         740.322133           1
# 22          22  2018       0  b4  성북동1가        1222.115385           1
# 23          23  2018       0  b4    종암동         649.106264           2
# 24          24  2018       0  b4   하월곡동         637.439247           2
# 42          42  2019       0  b1    미아동         726.835823           6
# 43          43  2019       0  b1     번동         573.942833           3
# 44          44  2019       0  b1    수유동         652.304282           3
# 45          45  2019       0  b2    공릉동         667.992634           4
# 46          46  2019       0  b2    상계동         708.072120           9
# 47          47  2019       0  b2    월계동         735.443322           4
# 48          48  2019       0  b3     창동         727.056884           2
# 54          54  2019       0  b4    길음동         912.488939           2
# 55          55  2019       0  b4  성북동1가        1017.779912           2
# 56          56  2019       0  b4    종암동         842.986962           4
# 57          57  2019       0  b4   하월곡동         769.047009           4
# 75          75  2020       0  b1    미아동         855.273448           3
# 76          76  2020       0  b1     번동         669.158130           2
# 77          77  2020       0  b1    수유동         656.441400           2
# 78          78  2020       0  b2    공릉동         758.493752           2
# 79          79  2020       0  b2    상계동         850.250584           7
# 80          80  2020       0  b2    월계동         895.487470           3
# 81          81  2020       0  b3     창동         867.961513           2
# 87          87  2020       0  b4    길음동        1124.798355           2
# 88          88  2020       0  b4  성북동1가         990.149457           1
# 89          89  2020       0  b4    종암동        1005.229062           2
# 90          90  2020       0  b4   하월곡동         903.532288           2
#
#     low_count  high_bus_sum  low_bus_sum  high_sub_average  low_sub_average  \
# 9           1            16            3        363.679423       122.574973
# 10          0            14            0        558.624425         0.000000
# 11          0            13            0        644.013008         0.000000
# 12          0             9            0        592.143548         0.000000
# 13          1            14            3        390.461125       303.704362
# 14          0             6            0        242.169332         0.000000
# 15          0             5            0         81.134111         0.000000
# 21          0             4            0        670.511997         0.000000
# 22          0             5            0        252.450941         0.000000
# 23          1             6            3        647.261550       700.697428
# 24          0             7            0        358.117923         0.000000
# 42          3            32           13        363.679423       238.436746
# 43          0            22            0        564.339477         0.000000
# 44          3            20            9        637.110588       715.425757
# 45          1            18            2        592.143548       376.740281
# 46          6            24           26        414.991563       400.891130
# 47          2            12           16        242.169332       114.415935
# 48          1            10            3         81.134111       678.902372
# 54          1             8            4        670.511997       317.670549
# 55          0            10            0        252.450941         0.000000
# 56          1            12            3        647.261550       700.697428
# 57          2            14            5        358.117923       459.502437
# 75          3            16           13        363.679423       238.436746
# 76          0            14            0        558.624425         0.000000
# 77          3            13            9        644.013008       715.425757
# 78          1            10            2        137.915154       376.740281
# 79          8            25           34        374.947574       357.770679
# 80          2             8           16        234.827785       114.415935
# 81          1             8            3        546.401701       678.902372
# 87          1             8            4        566.162139       317.670549
# 88          0             5            0        252.450941         0.000000
# 89          1             6            3        647.261550       700.697428
# 90          2             7            5        358.117923       459.502437
#
#         pop_avg
# 9   1682818.618
# 10  2258421.714
# 11  1630526.250
# 12  3356690.875
# 13  2196320.214
# 14  1069711.000
# 15  1391477.813
# 21  1261111.750
# 22  1535164.250
# 23  1037639.050
# 24  1725981.958
# 42  5543737.882
# 43  5592191.357
# 44  5338450.981
# 45  7650483.750
# 46  6164501.857
# 47  4228675.750
# 48  5543762.188
# 54  4312648.250
# 55  3480174.750
# 56  4006531.250
# 57  4925843.292
# 75  5618776.765
# 76  5632485.393
# 77  5350393.135
# 78  7960765.375
# 79  6381849.429
# 80  4329064.000
# 81  5373349.000
# 87  4201852.125
# 88  3204882.000
# 89  4268127.350
# 90  5295861.917

# %%
sns.regplot(x="high_count", y="high_bus_sum", data=g3) #0.9
# Out:
# <AxesSubplot:xlabel='high_count', ylabel='high_bus_sum'>

# %%
sns.regplot(x="high_count", y="high_bus_sum", data=bed4) #0.6
# Out:
# <AxesSubplot:xlabel='high_count', ylabel='high_bus_sum'>

# %%
sns.regplot(x="high_count", y="high_sub_average", data=g3)
# Out:
# <AxesSubplot:xlabel='high_count', ylabel='high_sub_average'>

# %%
sns.regplot(x="high_count", y="high_sub_average", data=bed4)
# Out:
# <AxesSubplot:xlabel='high_count', ylabel='high_sub_average'>

# %%
sns.pairplot(g3)
plt.show()

# %%
sns.scatterplot(x="high_count", y="high_bus_sum", hue="high_bus_sum", data=g3)
# Out:
# <AxesSubplot:xlabel='high_count', ylabel='high_bus_sum'>

# %%
sns.displot(data=g3, x="high_count", hue="high_count")

# %%
sns.kdeplot(data=df, x="high_bus_sum", hue="gu_num", multiple="stack")
# Out:
# <AxesSubplot:xlabel='high_bus_sum', ylabel='Density'>

# %%
sns.kdeplot(data=g3, x="high_bus_sum", hue="gu", multiple="stack")
# Out:
# <AxesSubplot:xlabel='high_bus_sum', ylabel='Density'>

# %%
sns.displot(data=df, x="high_bus_sum", hue="gu_num", multiple="stack")

# %%
sns.displot(data=g3, x="high_bus_sum", hue="gu", multiple="stack")

# %%
sns.displot(data=df, x="high_bus_sum", hue="low_bus_sum", col="gu_num")

# %%
sns.displot(data=g3, x="high_bus_sum", hue="low_bus_sum", col="gu")

# %%
sns.displot(data=bed4, x="high_bus_sum", hue="low_bus_sum", col="gu")
