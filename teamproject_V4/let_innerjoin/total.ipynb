# %%
import pandas as pd

# %%
a=pd.read_csv("a1.csv")

# %%
a
# Out:
#      year  gu_num   gu dong  average_sizetrade
# 0    2018       1  강남구  개포동        2350.950643
# 1    2018       1  강남구  논현동        1199.528213
# 2    2018       1  강남구  대치동        1929.110361
# 3    2018       1  강남구  도곡동        1478.389307
# 4    2018       1  강남구  삼성동        1773.421078
# ..    ...     ...  ...  ...                ...
# 220  2020       1  송파구  신천동        1969.937047
# 221  2020       1  송파구  오금동        1250.131272
# 222  2020       1  송파구  잠실동        2379.483057
# 223  2020       1  송파구  장지동        1677.511480
# 224  2020       1  송파구  풍납동        1338.296229
#
# [225 rows x 5 columns]

# %%
c=pd.read_csv("c1.csv")

# %%
c
# Out:
#      year  gu_num   gu  dong  high_count  low_count  high_bus_sum  \
# 0    2018       1  강남구   개포동           1          0             5
# 1    2018       1  강남구   논현동          20          1            52
# 2    2018       1  강남구  대치4동           0          3             0
# 3    2018       1  강남구   대치동          26          0            45
# 4    2018       1  강남구   도곡동           6          1            28
# ..    ...     ...  ...   ...         ...        ...           ...
# 196  2020       1  송파구  잠실2동           0          1             0
# 197  2020       1  송파구  잠실6동           0          4             0
# 198  2020       1  송파구   잠실동           7          1             9
# 199  2020       1  송파구  잠실본동           0          1             0
# 200  2020       1  송파구   장지동           2          1             6
#
#      low_bus_sum  high_sub_average  low_sub_average
# 0              0       1029.502388         0.000000
# 1              2        419.248044       134.404242
# ...

# %%
p=pd.read_csv("p1.csv")

# %%
p
# Out:
#      year  gu_num   gu dong       pop_avg
# 0    2018       1  강남구  개포동  6.263082e+05
# 1    2018       1  강남구  논현동  2.002405e+06
# 2    2018       1  강남구  대치동  2.275593e+06
# 3    2018       1  강남구  도곡동  1.288201e+06
# 4    2018       1  강남구  삼성동  1.542360e+06
# ..    ...     ...  ...  ...           ...
# 169  2020       1  송파구  석촌동  5.186844e+06
# 170  2020       1  송파구  송파동  5.279196e+06
# 171  2020       1  송파구  오금동  3.409495e+06
# 172  2020       1  송파구  잠실동  7.837714e+06
# 173  2020       1  송파구  풍납동  6.319992e+06
#
# [174 rows x 5 columns]

# %%
ac=pd.merge(a, c, on=['year','gu_num','gu','dong'])

# %%
ac
# Out:
#      year  gu_num   gu dong  average_sizetrade  high_count  low_count  \
# 0    2018       1  강남구  개포동        2350.950643           1          0
# 1    2018       1  강남구  논현동        1199.528213          20          1
# 2    2018       1  강남구  대치동        1929.110361          26          0
# 3    2018       1  강남구  도곡동        1478.389307           6          1
# 4    2018       1  강남구  삼성동        1773.421078          20          0
# ..    ...     ...  ...  ...                ...         ...        ...
# 118  2020       1  송파구  송파동        1462.550151           3          0
# 119  2020       1  송파구  신천동        1969.937047           7          2
# 120  2020       1  송파구  오금동        1250.131272           2          0
# 121  2020       1  송파구  잠실동        2379.483057           7          1
# 122  2020       1  송파구  장지동        1677.511480           2          1
#
#      high_bus_sum  low_bus_sum  high_sub_average  low_sub_average
# ...

# %%
acp=pd.merge(ac, p, on=['year','gu_num','gu','dong'])

# %%
acp
# Out:
#     year  gu_num   gu dong  average_sizetrade  high_count  low_count  \
# 0   2018       1  강남구  개포동        2350.950643           1          0
# 1   2018       1  강남구  논현동        1199.528213          20          1
# 2   2018       1  강남구  대치동        1929.110361          26          0
# 3   2018       1  강남구  도곡동        1478.389307           6          1
# 4   2018       1  강남구  삼성동        1773.421078          20          0
# ..   ...     ...  ...  ...                ...         ...        ...
# 94  2020       1  송파구  삼전동        1001.929997           1          1
# 95  2020       1  송파구  석촌동        1348.555295           2          0
# 96  2020       1  송파구  송파동        1462.550151           3          0
# 97  2020       1  송파구  오금동        1250.131272           2          0
# 98  2020       1  송파구  잠실동        2379.483057           7          1
#
#     high_bus_sum  low_bus_sum  high_sub_average  low_sub_average       pop_avg
# ...

# %%
import pandas_profiling

# %%
acp=acp.drop(['year','gu_num'],axis=1)

# %%
corr=acp.corr()

# %%
print(corr)
# Out:
#                    average_sizetrade  high_count  low_count  high_bus_sum  \
# average_sizetrade           1.000000    0.382129  -0.038965      0.235114
# high_count                  0.382129    1.000000   0.199375      0.903373
# low_count                  -0.038965    0.199375   1.000000      0.200282
# high_bus_sum                0.235114    0.903373   0.200282      1.000000
# low_bus_sum                -0.126676   -0.013560   0.805699      0.011037
# high_sub_average            0.347294   -0.026159   0.036908      0.003197
# low_sub_average            -0.061904    0.324937   0.522792      0.289596
# pop_avg                     0.022184    0.083751   0.370174      0.030385
#
#                    low_bus_sum  high_sub_average  low_sub_average   pop_avg
# average_sizetrade    -0.126676          0.347294        -0.061904  0.022184
# high_count           -0.013560         -0.026159         0.324937  0.083751
# ...

# %%
acp.profile_report()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.12.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2021-07-15 14:52:22.503972&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
bed4=acp[acp['gu_num']==0]

# %%
g3

# %%
g3=g3.drop(['year','gu_num'],axis=1)

# %%
corr=g3.corr()

# %%
print(corr)

# %%
g3.profile_report()

# %%
bed4=acp[acp['gu_num']==0]

# %%
bed4

# %%
bed4=bed4.drop(['year','gu_num'],axis=1)

# %%
corr=bed4.corr()

# %%
print(corr)

# %%
bed4.profile_report()
