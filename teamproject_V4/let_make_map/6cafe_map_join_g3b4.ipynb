# %%
pip install folium
# Out:
# ...
#
# ...

# %%
import folium
folium.__version__
# Out:
# '0.12.1'

# %%
import json

# %%
import pandas as pd

# 미리 만들어둔 데이터를 불러옵니다.

df = pd.read_csv('cafe6.csv',encoding='ansi')  #1개년
df.head()
# import csv
# df = open('seoul_starbucks.csv','r')
# df
# Out:
#      상가업소번호   상호명  시군구코드 시군구명       법정동코드 법정동명                  지번주소  \
# 0  25964875  스타벅스  11680  강남구  1168010600  대치동  서울특별시 강남구 대치동 936-15
# 1  20015708  스타벅스  11650  서초구  1165010800  서초동  서울특별시 서초구 서초동 1457-1
# 2  22934175  스타벅스  11680  강남구  1168010700  신사동  서울특별시 강남구 신사동 529-10
# 3  28520216  스타벅스  11305  강북구  1130510100  미아동   서울특별시 강북구 미아동 35-30
# 4  16095836  스타벅스  11680  강남구  1168010500  삼성동   서울특별시 강남구 삼성동 114-9
#
#                  도로명          경도         위도  ...     HubDist  star coffee  \
# 0   서울특별시 강남구 선릉로64길  127.053715  37.497946  ...  234.106825    87     79
# 1      서울특별시 서초구 효령로  127.014198  37.484386  ...  271.456342    45     34
# 2  서울특별시 강남구 논현로175길  127.021629  37.523184  ...  468.307786    87     79
# 3      서울특별시 강북구 도봉로  127.030686  37.611841  ...  355.394161     5      2
# 4     서울특별시 강남구 봉은사로  127.048501  37.511357  ...   31.892766    87     79
#
#    paul  mega  com  paik  high  low  total
# 0    15     7    5    11   181   23    204
# ...

# %%
geo_data = json.load(open('seoul_map.geojson', encoding='utf8'))

# %%
# 서울시 중심부의 위도, 경도 입니다.
center = [37.541, 126.986]

# 맵이 center 에 위치하고, zoom 레벨은 11로 시작하는 맵 m을 만듭니다.
m1 = folium.Map(location=center, zoom_start=10)

# Choropleth 레이어를 만들고, 맵 m에 추가합니다.
folium.Choropleth(
    geo_data=geo_data,
    data=df,
    columns=('시군구명','high'),
    key_on='feature.properties.SIG_KOR_NM',
    fill_color='BuPu',
    legend_name='고급화 카페 수',
).add_to(m1)

# 맵 m을 출력합니다.
m1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
for a in df.index:
    gu=df.loc[a,'상호명']
    if gu in("스타벅스","커피빈","폴바셋"):
        lat = df.loc[a,'위도']
        lng = df.loc[a,'경도']
        folium.Circle([lat,lng],popup=df.loc[a,'상가업소번호'],
                      color = 'blue',
                  tooltip=df.loc[a,'시군구명']).add_to(m1)
m1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
# 서울시 중심부의 위도, 경도 입니다.
center = [37.541, 126.986]

# 맵이 center 에 위치하고, zoom 레벨은 11로 시작하는 맵 m을 만듭니다.
m2 = folium.Map(location=center, zoom_start=10)

# Choropleth 레이어를 만들고, 맵 m에 추가합니다.
folium.Choropleth(
    geo_data=geo_data,
    data=df,
    columns=('시군구명','low'),
    key_on='feature.properties.SIG_KOR_NM',
    fill_color='BuPu',
    legend_name='저가형 카페 수',
).add_to(m2)

# 맵 m을 출력합니다.
m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
for a in df.index:
    gu=df.loc[a,'상호명']
    if gu in("메가커피","빽다방","컴포즈"):
        lat = df.loc[a,'위도']
        lng = df.loc[a,'경도']
        folium.Circle([lat,lng],popup=df.loc[a,'상가업소번호'],
                      color = 'blue',
                  tooltip=df.loc[a,'시군구명']).add_to(m2)
m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
