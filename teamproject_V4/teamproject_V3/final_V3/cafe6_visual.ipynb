# %%
import seaborn as sns

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('my-idea.csv',encoding='ansi')

# %%
df=df.replace('강남구','g1')

# %%
df=df.replace('서초구','g2')

# %%
df=df.replace('송파구','g3')

# %%
df=df.replace('강북구','b1')

# %%
df=df.replace('노원구','b2')

# %%
df=df.replace('도봉구','b3')

# %%
df=df.replace('성북구','b4')

# %%
df
# Out:
#      index  g3b4  gu dong  high_count  low_count  high_bus_sum  low_bus_sum  \
# 0        1     1  g1  개포동           1          0             5            0
# 1        2     1  g1  논현동          20          2            52            7
# 2        3     1  g1  대치동          26          3            45            4
# 3        4     1  g1  도곡동           6          1            28            4
# 4        5     1  g1  삼성동          20          1            45            0
# ..     ...   ...  ..  ...         ...        ...           ...          ...
# 148    164     1  g3  신천동           7          2            13            5
# 149    165     1  g3  오금동           2          0             5            0
# 150    166     1  g3  잠실동           7          1             9            4
# 151    167     1  g3  장지동           2          1             6            3
# 152    168     1  g3  풍납동           0          1             0            1
#
#      high_sub_average  low_sub_average  average_trade  average_sizetrade  year
# 0         1029.502173         0.000000   142210.62800        2350.950643  2018
# 1          419.247440       421.109606   113205.61800        1199.528213  2018
# 2          514.592585       565.141633   190018.34450        1929.110361  2018
# 3          413.884446       162.182751   162690.87180        1478.389307  2018
# 4          470.456501       750.724139   172511.37120        1773.421078  2018
# ..                ...              ...            ...                ...   ...
# 148        245.276827       204.296845   175000.50810        1969.937047  2020
# 149        190.955176         0.000000    99775.86788        1250.131272  2020
# 150        551.556183       177.950584   194692.40660        2379.483057  2020
# 151       1749.685274      1507.813878   118473.17070        1677.511480  2020
# 152          0.000000       458.589662    96334.32288        1338.296229  2020
#
# [153 rows x 13 columns]

# %%
g3=df[(df['g3b4']==1)]

# %%
g3
# Out:
#      index  g3b4  gu dong  high_count  low_count  high_bus_sum  low_bus_sum  \
# 0        1     1  g1  개포동           1          0             5            0
# 1        2     1  g1  논현동          20          2            52            7
# 2        3     1  g1  대치동          26          3            45            4
# 3        4     1  g1  도곡동           6          1            28            4
# 4        5     1  g1  삼성동          20          1            45            0
# ..     ...   ...  ..  ...         ...        ...           ...          ...
# 148    164     1  g3  신천동           7          2            13            5
# 149    165     1  g3  오금동           2          0             5            0
# 150    166     1  g3  잠실동           7          1             9            4
# 151    167     1  g3  장지동           2          1             6            3
# 152    168     1  g3  풍납동           0          1             0            1
#
#      high_sub_average  low_sub_average  average_trade  average_sizetrade  year
# 0         1029.502173         0.000000   142210.62800        2350.950643  2018
# 1          419.247440       421.109606   113205.61800        1199.528213  2018
# 2          514.592585       565.141633   190018.34450        1929.110361  2018
# 3          413.884446       162.182751   162690.87180        1478.389307  2018
# 4          470.456501       750.724139   172511.37120        1773.421078  2018
# ..                ...              ...            ...                ...   ...
# 148        245.276827       204.296845   175000.50810        1969.937047  2020
# 149        190.955176         0.000000    99775.86788        1250.131272  2020
# 150        551.556183       177.950584   194692.40660        2379.483057  2020
# 151       1749.685274      1507.813878   118473.17070        1677.511480  2020
# 152          0.000000       458.589662    96334.32288        1338.296229  2020
#
# [87 rows x 13 columns]

# %%
bed4=df[(df['g3b4']==0)]

# %%
bed4
# Out:
#      index  g3b4  gu   dong  high_count  low_count  high_bus_sum  low_bus_sum  \
# 11      12     0  b1    미아동           3          1            16            3
# 12      13     0  b1     번동           2          0            14            0
# 13      14     0  b1    수유동           2          1            13            1
# 14      15     0  b1    우이동           0          2             0            4
# 15      16     0  b2    공릉동           2          1             9            4
# ..     ...   ...  ..    ...         ...        ...           ...          ...
# 136    151     0  b4  성북동1가           1          0             5            0
# 137    153     0  b4    장위동           0          1             0            5
# 138    154     0  b4    정릉동           0          2             0            6
# 139    155     0  b4    종암동           2          0             6            0
# 140    156     0  b4   하월곡동           2          2             7            5
#
#      high_sub_average  low_sub_average  average_trade  average_sizetrade  year
# 11         363.679950       122.574184    46644.73434         611.833019  2018
# 12         558.622614         0.000000    34048.94336         516.053450  2018
# 13         644.012309       622.090160    35191.66667         460.761541  2018
# 14           0.000000       232.337772    38089.70588         465.259590  2018
# 15         592.145167       501.387393    36689.59829         559.081931  2018
# ..                ...              ...            ...                ...   ...
# 136        252.455200         0.000000    70625.00000         990.149457  2020
# 137          0.000000       975.817059    67052.96667         972.117800  2020
# 138          0.000000       595.839293    53779.14070         749.057065  2020
# 139        647.261985         0.000000    74888.22404        1005.229062  2020
# 140        358.119248       459.502155    70051.12033         903.532288  2020
#
# [66 rows x 13 columns]

# %%
sns.regplot(x="high_count", y="high_bus_sum", data=g3) #0.9
# Out:
# <AxesSubplot:xlabel='high_count', ylabel='high_bus_sum'>

# %%
sns.regplot(x="high_count", y="high_bus_sum", data=bed4) #0.6
# Out:
# <AxesSubplot:xlabel='high_count', ylabel='high_bus_sum'>

# %%
sns.regplot(x="high_count", y="high_sub_average", data=g3)
# Out:
# <AxesSubplot:xlabel='high_count', ylabel='high_sub_average'>

# %%
sns.regplot(x="high_count", y="high_sub_average", data=bed4)
# Out:
# <AxesSubplot:xlabel='high_count', ylabel='high_sub_average'>

# %%
sns.pairplot(g3)
plt.show()

# %%
sns.scatterplot(x="high_count", y="high_bus_sum", hue="high_bus_sum", data=g3)
# Out:
# <AxesSubplot:xlabel='high_count', ylabel='high_bus_sum'>

# %%
sns.displot(data=g3, x="high_count", hue="high_count")

# %%
sns.kdeplot(data=df, x="high_bus_sum", hue="g3b4", multiple="stack")
# Out:
# <AxesSubplot:xlabel='high_bus_sum', ylabel='Density'>

# %%
sns.kdeplot(data=g3, x="high_bus_sum", hue="gu", multiple="stack")
# Out:
# <AxesSubplot:xlabel='high_bus_sum', ylabel='Density'>

# %%
sns.displot(data=df, x="high_bus_sum", hue="g3b4", multiple="stack")

# %%
sns.displot(data=g3, x="high_bus_sum", hue="gu", multiple="stack")

# %%
sns.displot(data=df, x="high_bus_sum", hue="low_bus_sum", col="g3b4")

# %%
sns.displot(data=g3, x="high_bus_sum", hue="low_bus_sum", col="gu")

# %%
sns.displot(data=bed4, x="high_bus_sum", hue="low_bus_sum", col="gu")
