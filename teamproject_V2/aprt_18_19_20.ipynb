# %%
import pandas as pd

# %%
aprt_2018 = pd.read_csv('./aprt_2018_fin.csv', encoding='euc-kr')
aprt_2019 = pd.read_csv('./aprt_2019_fin.csv', encoding='euc-kr')
aprt_2020 = pd.read_csv('./aprt_2020_fin.csv', encoding='euc-kr')

# %%
aprt_2018=aprt_2018.append(aprt_2019)
aprt_18_19_20=aprt_2018.append(aprt_2020)

# %%
aprt_18_19_20=aprt_18_19_20.drop(columns='Unnamed: 0')

# %%
aprt_18_19_20
# Out:
#       구  전용면적_median  전용면적_max  전용면적_min  전용면적_mean  거래금액_median  거래금액_max  \
# 0   강남구       84.900   245.200   12.1000  94.349273       146000    640000
# 1   강동구       84.230   244.590   10.3215  77.736336        61900    170000
# 2   강북구       84.705   159.280   12.0200  77.630552        42000     89550
# 3   강서구       82.880   192.220   12.2200  74.832471        50000    134500
# 4   관악구       84.100   170.110   12.2100  76.637724        48000     88000
# ..  ...          ...       ...       ...        ...          ...       ...
# 20  용산구       84.940   317.360   13.0100  97.605635       136000    775000
# 21  은평구       84.170   205.960   12.2300  78.118720        63000    153000
# 22  종로구       80.850   244.937   12.0900  77.463155        74500    321000
# 23   중구       84.880   244.470   14.0800  83.482381        90750    304000
# 24  중랑구       66.254   203.770   12.0156  68.791370        50000    160000
#
# ...

# %%
aprt_18_19_20.reset_index(inplace=True)     #참고 sort_index(ascending=False) 역순으로 정렬하기

# %%
aprt_18_19_20.index=aprt_18_19_20.index+1

# %%
aprt_18_19_20
# Out:
#     index    구  전용면적_median  전용면적_max  전용면적_min  전용면적_mean  거래금액_median  \
# 1       0  강남구       84.900   245.200   12.1000  94.349273       146000
# 2       1  강동구       84.230   244.590   10.3215  77.736336        61900
# 3       2  강북구       84.705   159.280   12.0200  77.630552        42000
# 4       3  강서구       82.880   192.220   12.2200  74.832471        50000
# 5       4  관악구       84.100   170.110   12.2100  76.637724        48000
# ..    ...  ...          ...       ...       ...        ...          ...
# 71     20  용산구       84.940   317.360   13.0100  97.605635       136000
# 72     21  은평구       84.170   205.960   12.2300  78.118720        63000
# 73     22  종로구       80.850   244.937   12.0900  77.463155        74500
# 74     23   중구       84.880   244.470   14.0800  83.482381        90750
# 75     24  중랑구       66.254   203.770   12.0156  68.791370        50000
#
#     거래금액_max  거래금액_min      거래금액_mean  면적금액_median  면적금액_max  면적금액_min  \
# ...

# %%
aprt_18_19_20=aprt_18_19_20.drop(columns='index')

# %%
aprt_18_19_20
# Out:
#       구  전용면적_median  전용면적_max  전용면적_min  전용면적_mean  거래금액_median  거래금액_max  \
# 1   강남구       84.900   245.200   12.1000  94.349273       146000    640000
# 2   강동구       84.230   244.590   10.3215  77.736336        61900    170000
# 3   강북구       84.705   159.280   12.0200  77.630552        42000     89550
# 4   강서구       82.880   192.220   12.2200  74.832471        50000    134500
# 5   관악구       84.100   170.110   12.2100  76.637724        48000     88000
# ..  ...          ...       ...       ...        ...          ...       ...
# 71  용산구       84.940   317.360   13.0100  97.605635       136000    775000
# 72  은평구       84.170   205.960   12.2300  78.118720        63000    153000
# 73  종로구       80.850   244.937   12.0900  77.463155        74500    321000
# 74   중구       84.880   244.470   14.0800  83.482381        90750    304000
# 75  중랑구       66.254   203.770   12.0156  68.791370        50000    160000
#
# ...

# %%
aprt_18_19_20.to_csv('./aprt_18_19_20.csv',encoding='euc-kr')
